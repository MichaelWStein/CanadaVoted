# %% [markdown]
# Notebook for adding electoral district information to geojson

# %%
import pandas as pd
import json
import pprint
import math

pp = pprint.PrettyPrinter(indent=4)

# %%
#Loading the Statscan Data

statscanData = pd.read_csv("StatsCan_2016_ElecDist.csv")

statscanData.head()
# Out:
#    Unnamed: 0                   PROVINCE         GEO_UID  GEO_ID  \
# 0         NaN                   Province         Geo-UID  Geo-ID
# 1         0.0  Newfoundland and Labrador  2013A000410001   10001
# 2         1.0  Newfoundland and Labrador  2013A000410002   10002
# 3         2.0  Newfoundland and Labrador  2013A000410003   10003
# 4         3.0  Newfoundland and Labrador  2013A000410004   10004
#
#                                  NAME    Population, 2016  \
# 0                      Name of Riding  Population in 2016
# 1                              Avalon               86494
# 2           Bonavista--Burin--Trinity               74116
# 3  Coast of Bays--Central--Notre Dame               77680
# 4                            Labrador               27197
#
#                  Population density                     Average age  \
# 0  Population density per squakre km  Average age of the population
# 1                               13.4                           42.4
# 2                                4.4                           47.4
# 3                                  2                           46.5
# 4                                0.1                             37
#
#              Average household size                                 English  \
# 0  Average household size (persons)  English Mother tongue, single response
# 1                               2.4                                   84870
# 2                               2.3                                   73005
# 3                               2.3                                   76320
# 4                               2.7                                   23190
#
#                                  French  \
# 0  Fench Mother tongue, single response
# 1                                   195
# 2                                   175
# 3                                   150
# 4                                   410
#
#                               Non-official languages  \
# 0  Non-official language as mother tongue, single...
# 1                                                480
# 2                                                370
# 3                                                485
# 4                                               3225
#
#                           Average total income  \
# 0  Average income among recipients in 2015 ($)
# 1                                        48083
# 2                                        38924
# 3                                        38258
# 4                                        56347
#
#                               poverty rate  \
# 0  % of persons 18 to 64 living in poverty
# 1                                      9.3
# 2                                     12.6
# 3                                       15
# 4                                      6.5
#
#                                   Non-immigrants  \
# 0  Number of non-immigrants living in the riding
# 1                                          84185
# 2                                          72110
# 3                                          75620
# 4                                          25805
#
#                                   Immigrants
# 0  Number of Immigrants living in the riding
# 1                                       1020
# 2                                        695
# 3                                        740
# 4                                        805

# %%
statscanData.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 339 entries, 0 to 338
# Data columns (total 16 columns):
# Unnamed: 0                    338 non-null float64
# PROVINCE                      339 non-null object
# GEO_UID                       339 non-null object
# GEO_ID                        339 non-null object
# NAME                          339 non-null object
# Population, 2016              339 non-null object
# Population density            339 non-null object
# Average age                   339 non-null object
# Average household size        339 non-null object
#     English                   339 non-null object
#       French                  339 non-null object
#     Non-official languages    339 non-null object
#     Average total income      339 non-null object
# poverty rate                  336 non-null object
#   Non-immigrants              339 non-null object
#   Immigrants                  339 non-null object
# dtypes: float64(1), object(15)
# memory usage: 42.5+ KB

# %%
#Dataframe - don't need information in first row, delete and clean up the index

statscanData = statscanData[statscanData['PROVINCE'] != 'Province']
statscanData = statscanData.reset_index()
statscanData = statscanData.drop(["index", "Unnamed: 0"], axis=1)

#Rename columns to get rid of blanks
statscanData = statscanData.rename(columns={'      French':'French','    English':'English',\
'    Non-official languages':'Non_official_languages','    Average total income':'Average_total_income',\
'  Non-immigrants':'Non_immigrants','  Immigrants':'Immigrants','Population density ': 'Population_density',\
'Population, 2016':'Population_2016', 'Average household size': 'Average_household_size', 'poverty rate': 'poverty_rate', 'Average age': 'Average_age'})

statscanData.head()
# Out:
#                     PROVINCE         GEO_UID GEO_ID  \
# 0  Newfoundland and Labrador  2013A000410001  10001
# 1  Newfoundland and Labrador  2013A000410002  10002
# 2  Newfoundland and Labrador  2013A000410003  10003
# 3  Newfoundland and Labrador  2013A000410004  10004
# 4  Newfoundland and Labrador  2013A000410005  10005
#
#                                  NAME Population_2016 Population_density  \
# 0                              Avalon           86494               13.4
# 1           Bonavista--Burin--Trinity           74116                4.4
# 2  Coast of Bays--Central--Notre Dame           77680                  2
# 3                            Labrador           27197                0.1
# 4                Long Range Mountains           86553                2.3
#
#   Average_age Average_household_size English French Non_official_languages  \
# 0        42.4                    2.4   84870    195                    480
# 1        47.4                    2.3   73005    175                    370
# 2        46.5                    2.3   76320    150                    485
# 3          37                    2.7   23190    410                   3225
# 4        46.5                    2.3   84485    565                    620
#
#   Average_total_income poverty_rate Non_immigrants Immigrants
# 0                48083          9.3          84185       1020
# 1                38924         12.6          72110        695
# 2                38258           15          75620        740
# 3                56347          6.5          25805        805
# 4                38151         14.9          83755       1190

# %%
statscanData.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 338 entries, 0 to 337
# Data columns (total 15 columns):
# PROVINCE                  338 non-null object
# GEO_UID                   338 non-null object
# GEO_ID                    338 non-null object
# NAME                      338 non-null object
# Population_2016           338 non-null object
# Population_density        338 non-null object
# Average_age               338 non-null object
# Average_household_size    338 non-null object
# English                   338 non-null object
# French                    338 non-null object
# Non_official_languages    338 non-null object
# Average_total_income      338 non-null object
# poverty_rate              335 non-null object
# Non_immigrants            338 non-null object
# Immigrants                338 non-null object
# dtypes: object(15)
# memory usage: 39.7+ KB

# %%
#Adjusting dataframe - percentage for languages and immigrants

for i in range(0, statscanData.shape[0]):
    a = float(statscanData.loc[i, 'Population_2016'])
    b = float(statscanData.loc[i, 'English'])
    c = float(statscanData.loc[i, 'French'])
    d = float(statscanData.loc[i, 'Non_official_languages'])
    e = float(statscanData.loc[i, 'Non_immigrants'])
    f = float(statscanData.loc[i, 'Immigrants'])
    statscanData.at[i, "English"] = b/a
    statscanData.at[i, 'French'] = c/a
    statscanData.at[i, 'Non_official_languages'] = d/a
    statscanData.at[i, 'Immigrants'] = f/a
    statscanData.at[i, 'Non_immigrants'] = e/a
    #print(a, b, c, d, e, f)

statscanData.head()
# Out:
#                     PROVINCE         GEO_UID GEO_ID  \
# 0  Newfoundland and Labrador  2013A000410001  10001
# 1  Newfoundland and Labrador  2013A000410002  10002
# 2  Newfoundland and Labrador  2013A000410003  10003
# 3  Newfoundland and Labrador  2013A000410004  10004
# 4  Newfoundland and Labrador  2013A000410005  10005
#
#                                  NAME Population_2016 Population_density  \
# 0                              Avalon           86494               13.4
# 1           Bonavista--Burin--Trinity           74116                4.4
# 2  Coast of Bays--Central--Notre Dame           77680                  2
# 3                            Labrador           27197                0.1
# 4                Long Range Mountains           86553                2.3
#
#   Average_age Average_household_size   English      French  \
# 0        42.4                    2.4  0.981224  0.00225449
# 1        47.4                    2.3   0.98501  0.00236116
# 2        46.5                    2.3  0.982492    0.001931
# 3          37                    2.7  0.852668   0.0150752
# 4        46.5                    2.3  0.976107  0.00652779
#
#   Non_official_languages Average_total_income poverty_rate Non_immigrants  \
# 0             0.00554952                48083          9.3       0.973305
# 1             0.00499217                38924         12.6       0.972934
# 2             0.00624356                38258           15       0.973481
# 3               0.118579                56347          6.5       0.948818
# 4             0.00716324                38151         14.9       0.967673
#
#    Immigrants
# 0   0.0117927
# 1  0.00937719
# 2  0.00952626
# 3   0.0295989
# 4   0.0137488

# %%
#Creating a list of dictionaries - contains the GEO_ID as key and the index as value.
#This list can then be used to retrieve infor for the GeoJson

geoid = []

for i in range(0, statscanData.shape[0]):
    dict_key = str(statscanData.loc[i, "GEO_ID"]).strip()
    geoid.append({dict_key: i})
    
#print(geoid)

# %%
#Overview of the Properties in the json-file
#Opens the json and looks at the properties - no changes

with open('electoral_districts.geojson', 'r') as read_file:
        data_test = json.load(read_file)

detail_list = data_test["features"]

print(len(detail_list))
#for i in range(len(detail_list)):
#    detail_dict = detail_list[i]
#    properties = (detail_dict["properties"])
#    #print(str(properties.get("FED_NUM")).strip())

#print(properties)
# Out:
# 347

# %%
#Simplifying the json properties - contains only the FEDNUM (as a string with possible spaces at beginning and end cut off
# to ensure consistency)

for i in range(len(detail_list)):
    detail_dict = detail_list[i]
    properties = detail_dict["properties"]
    a = str(properties.get("FED_NUM")).strip()
    properties["FED_NUM"] = a
    for e in ['FEDNUM', 'FRNAME', 'PROVCODE', 'DECPOPCNT']:
        properties.pop(e)
    #print(properties)

# %%
#Looping through the dictionary - rebuild the properties field with information from the dataframe

#Prepwork: Names of the Columns I want to retrieve from the dataframe

value_list = []

columns_retr = ["NAME", "Population_2016", "Population_density", "Average_age", "Average_household_size",\
               "English", "French", "Non_official_languages", "Average_total_income", "poverty_rate", "Non_immigrants",\
                "Immigrants"]

for i in range(len(detail_list)):
    detail_dict = detail_list[i]
    properties = (detail_dict["properties"])
    #print(str(properties.get("FED_NUM")).strip())
    reference = properties['FED_NUM']
    for j in range(len(geoid)):
        #Selecting the correct row in the dataframe
        if reference in geoid[j].keys():
            index = geoid[j][reference]
            print(i, "success", index)
            for k in range(len(columns_retr)):
                s = statscanData.loc[index, columns_retr[k]]
                if 'N' in str(s):
                    print(s, index)
                if type(s) == float:
                    s = round(s, 2)
                if not isinstance(s, str):
                    if math.isnan(s):
                        s = "Na"
                t = columns_retr[k]
                properties[t] = s
                #print(s, t, type(s))
            #print(properties)
        #else:
            #print("failure")

#pp.pprint(detail_list)
# Out:
# 0 success 138
# Etobicoke North 138
# 1 success 141
# 2 success 275
# 3 success 276
# 4 success 279
# 5 success 280
# 6 success 281
# 7 success 282
# 8 success 283
# 9 success 96
# 10 success 97
# 11 success 98
# 12 success 99
# 13 success 100
# 14 success 101
# 15 success 102
# 16 success 103
# 17 success 107
# 18 success 104
# 19 success 109
# 20 success 131
# 21 success 132
# 22 success 134
# 23 success 71
# 24 success 73
# 25 success 142
# Haldimand--Norfolk 142
# 26 success 166
# 27 success 167
# 28 success 277
# 29 success 285
# 30 success 278
# 31 success 286
# 32 success 284
# 33 success 287
# 34 success 288
# 35 success 290
# 36 success 291
# 37 success 292
# 38 success 72
# 39 success 289
# 40 success 74
# 41 success 75
# 42 success 168
# 43 success 105
# 44 success 106
# 45 success 169
# 46 success 335
# 47 success 108
# 48 success 337
# Nunavut 337
# 49 success 336
# Northwest Territories 336
# 50 success 259
# 51 success 260
# 52 success 261
# 53 success 262
# 54 success 130
# 55 success 139
# 56 success 140
# 57 success 146
# 58 success 147
# 59 success 143
# 60 success 144
# 61 success 145
# 62 success 148
# 63 success 149
# 64 success 247
# 65 success 248
# 66 success 249
# 67 success 245
# 68 success 246
# 69 success 250
# 70 success 251
# 71 success 252
# 72 success 253
# 73 success 254
# 74 success 257
# 75 success 61
# 76 success 62
# 77 success 150
# 78 success 76
# 79 success 151
# 80 success 152
# 81 success 155
# 82 success 157
# 83 success 158
# 84 success 255
# 85 success 256
# 86 success 258
# 87 success 63
# 88 success 67
# 89 success 64
# 90 success 65
# 91 success 66
# 92 success 77
# 93 success 77
# 94 success 77
# 95 success 78
# 96 success 79
# 97 success 263
# 98 success 264
# 99 success 266
# 100 success 269
# 101 success 133
# 102 success 156
# 103 success 159
# 104 success 163
# 105 success 153
# 106 success 154
# 107 success 57
# 108 success 265
# 109 success 57
# 110 success 136
# 111 success 135
# 112 success 161
# London North Centre 161
# 113 success 80
# 114 success 81
# 115 success 160
# 116 success 271
# 117 success 267
# Calgary Nose Hill 267
# 118 success 162
# 119 success 268
# 120 success 270
# 121 success 137
# 122 success 272
# 123 success 273
# 124 success 68
# 125 success 69
# 126 success 70
# 127 success 164
# 128 success 165
# 129 success 274
# 130 success 93
# 131 success 94
# Rivière-du-Nord 94
# 132 success 95
# 133 success 170
# 134 success 171
# 135 success 172
# 136 success 178
# Nickel Belt 178
# 137 success 179
# Nipissing--Timiskaming 179
# 138 success 180
# Northumberland--Peterborough South 180
# 139 success 225
# 140 success 226
# 141 success 332
# 142 success 333
# 143 success 334
# 144 success 116
# 145 success 173
# Nepean 173
# 146 success 174
# Newmarket--Aurora 174
# 147 success 227
# 148 success 175
# Niagara Centre 175
# 149 success 176
# Niagara Falls 176
# 150 success 177
# Niagara West 177
# 151 success 181
# 152 success 182
# Oakville North--Burlington 182
# 153 success 183
# 154 success 184
# 155 success 189
# 156 success 228
# 157 success 229
# 158 success 230
# 159 success 231
# 160 success 231
# 161 success 110
# 162 success 111
# 163 success 112
# 164 success 113
# 165 success 114
# 166 success 115
# 167 success 185
# 168 success 186
# 169 success 190
# 170 success 191
# 171 success 232
# 172 success 233
# 173 success 234
# Dauphin--Swan River--Neepawa 234
# 174 success 235
# 175 success 236
# 176 success 237
# 177 success 238
# 178 success 239
# 179 success 7
# 180 success 8
# 181 success 9
# 182 success 187
# 183 success 188
# Ottawa West--Nepean 188
# 184 success 192
# 185 success 193
# 186 success 194
# 187 success 195
# Renfrew--Nipissing--Pembroke 195
# 188 success 197
# 189 success 240
# 190 success 240
# 191 success 240
# 192 success 240
# 193 success 241
# 194 success 242
# Winnipeg North 242
# 195 success 243
# 196 success 244
# 197 success 296
# 198 success 10
# 199 success 0
# 200 success 1
# 201 success 2
# Coast of Bays--Central--Notre Dame 2
# 202 success 3
# 203 success 4
# 204 success 5
# 205 success 6
# 206 success 11
# 207 success 12
# Central Nova 12
# 208 success 13
# 209 success 196
# 210 success 198
# 211 success 199
# 212 success 58
# 213 success 59
# 214 success 60
# 215 success 14
# 216 success 15
# 217 success 15
# 218 success 16
# 219 success 17
# 220 success 18
# 221 success 19
# 222 success 20
# 223 success 21
# West Nova 21
# 224 success 22
# 225 success 23
# 226 success 24
# 227 success 25
# 228 success 26
# 229 success 27
# 230 success 29
# New Brunswick Southwest 29
# 231 success 30
# 232 success 31
# 233 success 32
# Abitibi--Baie-James--Nunavik--Eeyou 32
# 234 success 33
# 235 success 200
# 236 success 201
# 237 success 293
# 238 success 294
# Burnaby North--Seymour 294
# 239 success 297
# Central Okanagan--Similkameen--Nicola 297
# 240 success 298
# 241 success 300
# 242 success 301
# 243 success 301
# 244 success 302
# 245 success 305
# 246 success 28
# 247 success 34
# 248 success 35
# 249 success 36
# Argenteuil--La Petite-Nation 36
# 250 success 37
# 251 success 38
# 252 success 202
# 253 success 203
# 254 success 204
# 255 success 295
# 256 success 299
# 257 success 303
# 258 success 306
# 259 success 307
# 260 success 39
# 261 success 40
# Bécancour--Nicolet--Saurel 40
# 262 success 41
# 263 success 42
# 264 success 43
# 265 success 44
# 266 success 45
# 267 success 46
# 268 success 47
# 269 success 48
# 270 success 49
# Rimouski-Neigette--Témiscouata--Les Basques 49
# 271 success 119
# Brampton North 119
# 272 success 117
# 273 success 118
# 274 success 120
# 275 success 205
# Scarborough North 205
# 276 success 206
# 277 success 207
# 278 success 208
# 279 success 209
# Simcoe North 209
# 280 success 304
# 281 success 308
# 282 success 309
# 283 success 310
# Nanaimo--Ladysmith 310
# 284 success 311
# New Westminster--Burnaby 311
# 285 success 312
# North Okanagan--Shuswap 312
# 286 success 313
# North Vancouver 313
# 287 success 314
# 288 success 50
# 289 success 51
# 290 success 52
# 291 success 121
# 292 success 122
# 293 success 123
# 294 success 210
# 295 success 211
# 296 success 212
# 297 success 213
# 298 success 214
# 299 success 215
# Thunder Bay--Superior North 215
# 300 success 216
# 301 success 217
# 302 success 222
# 303 success 315
# 304 success 316
# Prince George--Peace River--Northern Rockies 316
# 305 success 317
# 306 success 318
# 307 success 319
# 308 success 320
# 309 success 321
# 310 success 53
# 311 success 54
# 312 success 55
# 313 success 56
# 314 success 124
# 315 success 125
# 316 success 126
# 317 success 218
# 318 success 219
# 319 success 220
# 320 success 322
# 321 success 323
# 322 success 324
# 323 success 325
# Surrey--Newton 325
# 324 success 83
# 325 success 84
# Notre-Dame-de-Grâce--Westmount 84
# 326 success 85
# 327 success 86
# 328 success 82
# 329 success 127
# 330 success 128
# 331 success 129
# Don Valley North 129
# 332 success 221
# 333 success 223
# 334 success 224
# 335 success 326
# 336 success 327
# 337 success 328
# 338 success 329
# North Island--Powell River 329
# 339 success 330
# 340 success 331
# 341 success 87
# 342 success 88
# 343 success 89
# 344 success 90
# 345 success 91
# 346 success 92

# %%
#print(data_test)

# %%
with open('data_upd.geojson', 'w', encoding='utf-8') as f:
          json.dump(data_test, f)
